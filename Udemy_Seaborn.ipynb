# %% [markdown]
# ## Udemy Seaborn
# ## https://seaborn.pydata.org

# %% [markdown]
# #### Les lignes sous-dessous commentées nous ont permis d'installer la librairie Seaborn
# #### Attention, il est important de ne pas relancer les lignes ci-dessus pour garder les informations !!!

# %%
import sys

# %%
# !echo path
# Out:
# path

# %%
# !echo $PATH
# Out:
# $PATH

# %%
# sys.path
# Out:
# ['C:\\Users\\LM167708\\New_Notebook',
#  'C:\\JupyterLab\\resources\\jlab_server\\python38.zip',
#  'C:\\JupyterLab\\resources\\jlab_server\\DLLs',
#  'C:\\JupyterLab\\resources\\jlab_server\\lib',
#  'C:\\JupyterLab\\resources\\jlab_server',
#  '',
#  'C:\\JupyterLab\\resources\\jlab_server\\lib\\site-packages',
#  'C:\\JupyterLab\\resources\\jlab_server\\lib\\site-packages\\win32',
#  'C:\\JupyterLab\\resources\\jlab_server\\lib\\site-packages\\win32\\lib',
#  'C:\\JupyterLab\\resources\\jlab_server\\lib\\site-packages\\Pythonwin',
#  'C:\\JupyterLab\\resources\\jlab_server\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LM167708\\.ipython']

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  C:\JupyterLab\resources\jlab_server
#                          C:\Users\LM167708\AppData\Local\Continuum\anaconda3
#                          C:\Users\LM167708\AppData\Local\Continuum\anaconda3\envs\Pacbio_tools
#                          C:\Users\LM167708\AppData\Local\Continuum\anaconda3\envs\simple

# %%
# !{sys.executable} -m pip install seaborn

# %% [markdown]
# #### Attention, il est important de ne pas relancer les lignes ci-dessus pour garder les informations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Un peu de Matplotlib avant Seaborn
# ### http://www.matplotlib.org
# ### https://github.com/matplotlib/matplotlib
# ### https://matplotlib.org.2.0.2/gallery.html

# %%
a=np.linspace(0,10,11)
b=a**2
x=np.arange(0,10)
y=2*x

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(a,b)

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
axes[0][0].plot(x,y)
axes[1][1].plot(a,b)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
axes[0][0].plot(x,y)
axes[1][0].plot(x,y)
axes[1][0].set_ylabel('Label Y - Axes 1,0')
axes[1][0].set_xlim(2,6)
axes[1][1].plot(a,b)
axes[1][1].set_title('Titre 1,1')
fig.suptitle('Titre au niveau Figure', fontsize=12)
fig.subplots_adjust(wspace=0.8,hspace=0.4)
fig.savefig('new1_subplot',bbox_inches='tight')
# wspace=0.8 signifie 80% d'un espace de figure

# %%
z = np.linspace(0,11,10)
fig1 = plt.figure()
ax = fig1.add_axes([0,0,1,1])
ax.plot(z,z, label = 'X vs X', color='green',linewidth=2)
# Site web pour les couleurs hex color picker
ax.plot(z,z**2, label = 'X vs X^2', color = '#42d4f5',lw=2, marker='s', markersize=10, markerfacecolor='red',
       markeredgewidth=4,markeredgecolor='orange')
# options de type de ligne possible '--','-','-.',':','steps'
ax.plot(z,z**3, label = 'X vs X^3', color='#f5b942',lw=2, ls='-.', marker='o', markersize=6)
#localisation du point inférieur gauche de la légende
ax.legend(loc=(1.1,0.4))

# %%
df = pd.read_csv("auto.csv")

# %%
df.head()
# Out:
#     mpg  displ   hp  weight  accel  origin  size
# 0  18.0  250.0   88    3139   14.5      US  15.0
# 1   9.0  304.0  193    4732   18.5      US  20.0
# 2  36.1   91.0   60    1800   16.4    Asia  10.0
# 3  18.5  250.0   98    3525   19.0      US  15.0
# 4  34.3   97.0   78    2188   15.8  Europe  10.0

# %%
sns.scatterplot(x='displ',y='weight',data=df)
plt.show()

# %%
plt.figure(figsize=(3,4),dpi=100)
sns.scatterplot(x='displ',y='weight',data=df)
# Out:
# <AxesSubplot:xlabel='displ', ylabel='weight'>

# %%
plt.figure(figsize=(3,4),dpi=100)
sns.scatterplot(x='displ',y='weight',data=df, hue='origin')
plt.savefig('auto.png')

# %% [markdown]
# #### https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
plt.figure(figsize=(3,4),dpi=100)
sns.scatterplot(x='displ',y='weight',data=df, style='origin',palette='Dark2',alpha=0.4)
# Out:
# <AxesSubplot:xlabel='displ', ylabel='weight'>

# %% [markdown]
# ## Les diagrammes de distributions
# ### - Diagramme Rug (ordonnée ininterprétable)
# ### - Histogramme
# ### - Diagramme KDE (Kernel Density Estimation)

# %%
sns.rugplot(x='displ',data=df)
# Out:
# <AxesSubplot:xlabel='displ'>

# %%
sns.rugplot(x='displ',data=df, height=0.5)
# Out:
# <AxesSubplot:xlabel='displ'>

# %%
# n'utilisez pas distplot
sns.set(style='whitegrid')
sns.displot(x='displ',data=df, hue='origin',palette='Dark2', kde=True,rug=True)

# %%
sns.histplot(x='displ',data=df)
# Out:
# <AxesSubplot:xlabel='displ', ylabel='Count'>

# %%
sns.kdeplot(x='displ',data=df)
# Out:
# <AxesSubplot:xlabel='displ', ylabel='Density'>

# %%
np.random.seed(42)
sample_ages = np.random.randint(0,100,1000)
sample_ages = pd.DataFrame(sample_ages,columns=['age'])
sns.rugplot(data=sample_ages,x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.kdeplot(data=sample_ages,x='age',clip=[0,100])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## Diagramme catégoriel
# ### Diagramme de comptage : Countplot
# ### Diagramme à barres : barplot

# %%
df['origin'].value_counts()
# Out:
# US        245
# Asia       79
# Europe     68
# Name: origin, dtype: int64

# %%
sns.countplot(data=df, x='origin')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
sns.countplot(data=df, x='size',hue='origin')
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.barplot(data=df,y='size',x='origin', estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='size'>

# %%
sns.barplot(data=df,y='size',x='origin', estimator=np.mean, ci='sd')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='size'>

# %% [markdown]
# ## Distribution au sein de catégories
# ### Boxplot, Violinplot, Swarmplot et Boxenplot(Letter-Value plot)

# %% [markdown]
# ### Boxenplot divise en quantiles
# ![image.png](attachment:53c9ca2c-6485-40fd-b274-ab3d88b55e1e.png)

# %%
sns.boxplot(data=df, y='displ', x='size', hue='origin')
plt.legend(bbox_to_anchor=(1.05,1))

# %%
sns.violinplot(data=df, y='displ', x='size', hue='origin')
# Out:
# <AxesSubplot:xlabel='size', ylabel='displ'>

# %%
sns.violinplot(data=df, x='size', y='displ', split=True, inner='quartile')
# Out:
# <AxesSubplot:xlabel='size', ylabel='displ'>

# %%
plt.figure(figsize=(5,4),dpi=150)
sns.swarmplot(data=df, y='displ', x='size', size=2)
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\JupyterLab\resources\jlab_server\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='size', ylabel='displ'>

# %%
sns.boxenplot(data=df, y='displ', x='size', hue='origin')
plt.legend(bbox_to_anchor=(1.05,1))

# %% [markdown]
# ## Diagramme en 2 dimensions
# ### Jointplot()
# ### Pairplot()

# %%
sns.jointplot(data=df, y='displ', x='size', hue='origin')

# %%
sns.jointplot(data=df, y='displ', x='size', kind='hex')

# %%
sns.jointplot(data=df, y='displ', x='size', kind='kde')

# %%
sns.pairplot(data=df)

# %% [markdown]
# ## Grille de diagramme

# %%
sns.catplot(data=df, y='displ', x='size', kind='box', row='origin')

# %%
sns.catplot(data=df, y='displ', x='size', kind='box', col='origin')

# %%
g = sns.PairGrid(df)

g = g.map_upper(sns.scatterplot)
g = g.map_diag(sns.kdeplot)
g = g.map_lower(sns.kdeplot)

# %% [markdown]
# ## Diagramme matriciel (carte de fréquentation)
# ### Heatmap()
# ### Clustermap()

# %%
df2 = pd.read_csv('country_table.csv')
df2 = df2.set_index('Countries')

# %%
df2.head()
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# LATIN AMERICA AND THE CARIBBEAN                 14.570         8.89
# NORTHERN AMERICA                                 5.563         6.11

# %%
sns.heatmap(df2)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
# Attention l'age est en année contrairement à des pourcentages dans les autres colonnes
sns.heatmap(df2.drop('Life expectancy',axis=1),linewidth=0.5,annot=True)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df2.drop('Life expectancy',axis=1),linewidth=0.5,annot=True,cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=150)
sns.clustermap(df2.drop('Life expectancy',axis=1),linewidth=0.5,annot=True)

# %%
# On peut stopper le clustering des colonnes
plt.figure(dpi=150)
sns.clustermap(df2.drop('Life expectancy',axis=1),linewidth=0.5,annot=True,col_cluster=False)
